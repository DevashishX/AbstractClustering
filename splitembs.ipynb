# %%
import pandas as pd
import numpy as np

df = pd.read_pickle("./MegaSentEmbs/repository_embedding_64_2013-03-19.pkl")

# %%
df
# Out:
#             id                                              title  \
# 0      6182249          Foundry Lane junction with Harehills Lane
# 1      6182251         Foundry Lane junction  with Harehills Lane
# 2      6182253     Harehills Lane and Buller Grove, telephone box
# 3      6182256                Branch Church street, surplus land.
# 4      6182259                         Shannon Street Social Club
# ...        ...                                                ...
# 57387  8791605              Back Sidlaw Terrace, terraced housing
# 57388  8791606                   Mexborough Street, looking north
# 57389  8791607  Alcester Road, Alcester Street, following demo...
# 57390  8791608                Middleton Railway Line at Moor Road
# 57391  8791609                                      Can You Help?
#
#                                                 abstract  \
# 0      [26th, september, number, leslie, thompson, ba...
# ...

# %%
l = len(df.index)
l
# Out:
# 57392

# %%
ind = l/8
ind
# Out:
# 7174.0

# %%
7174*8
# Out:
# 57392

# %%
temp1 = df[0:7174]
temp2 = df[7174:14348]
temp3 = df[14348:21522]
temp4 = df[21522:28696]
temp5 = df[28696:35870]
temp6 = df[35870:43044]
temp7 = df[43044:50218]
temp8 = df[50218:57392]

arr = [temp1, temp2, temp3, temp4, temp5, temp6, temp7, temp8]
sumx = 0
# for i in range(len(arr)):
#     sumx = sumx + len(arr[i].index)
#     This does not work 
#     arr[i] = arr[i].reset_index(drop=True)
# print(sumx)

#I have no clue why this works, some weird referencing issue 
temp1 = temp1.reset_index(drop=True)
temp2 = temp2.reset_index(drop=True)
temp3 = temp3.reset_index(drop=True)
temp4 = temp4.reset_index(drop=True)
temp5 = temp5.reset_index(drop=True)
temp6 = temp6.reset_index(drop=True)
temp7 = temp7.reset_index(drop=True)
temp8 = temp8.reset_index(drop=True)

# %%
#### # temp2.reset_index(drop=True)
# rn = list(range(int(ind)))
# # temp2.reindex(rn, method=None)
# temp2.reset_index(drop=True)
temp1.to_pickle("repository_embedding_64A_2013-03-19.pkl")
temp2.to_pickle("repository_embedding_64B_2013-03-19.pkl")
temp3.to_pickle("repository_embedding_64C_2013-03-19.pkl")
temp4.to_pickle("repository_embedding_64D_2013-03-19.pkl")
temp5.to_pickle("repository_embedding_64E_2013-03-19.pkl")
temp6.to_pickle("repository_embedding_64F_2013-03-19.pkl")
temp7.to_pickle("repository_embedding_64G_2013-03-19.pkl")
temp8.to_pickle("repository_embedding_64H_2013-03-19.pkl")

# %%
# Out:
#             id                            title  \
# 14348  7388662      Roundhay Park, Donkey Rides
# 14349  7388663         Mount Pleasant nos. 1, 3
# 14350  7388665         Roundhay Park, Boathouse
# 14351  7388666  Monkton Terrace, Monkton Street
# 14352  7388667     Roundhay Park, Waterloo Lake
# ...        ...                              ...
# 21517  7395839      Devon Terrace, nos. 21 - 23
# 21518  7395840    Sheepscar Green, numbers 2-14
# 21519  7395841         Devon Terrace Waste Lane
# 21520  7395842   Aysgarth Terrace, nos. 17 - 21
# 21521  7395843                    Roundhay Road
#
#                                                 abstract  \
# 14348  [6th, august, august, bank, holiday, war, time...
# 14349  [undated, two, property, mount, pleasant, numb...
# 14350  [undated, view, roundhay, park, show, end, boa...
# 14351  [view, show, back, back, property, monkton, st...
# 14352  [waterloo, lake, boat, house, roof, boathouse,...
# ...

# %%
rd = pd.read_pickle("repository_embedding_64A_2013-03-19.pkl")
rd
# Out:
#            id                                           title  \
# 0     6182249       Foundry Lane junction with Harehills Lane
# 1     6182251      Foundry Lane junction  with Harehills Lane
# 2     6182253  Harehills Lane and Buller Grove, telephone box
# 3     6182256             Branch Church street, surplus land.
# 4     6182259                      Shannon Street Social Club
# ...       ...                                             ...
# 7169  7381368                                       York Road
# 7170  7381369                                    Albion Place
# 7171  7381370                                Sholebroke Mount
# 7172  7381371                                       Park Lane
# 7173  7381372                           Harrogate Road no.490
#
#                                                abstract  \
# 0     [26th, september, number, leslie, thompson, ba...
# 1     [26th, september, harehills, lane, number, bri...
# ...
